# %% [markdown]
# #  Introduction
#
# To understand how Blockchain works, we must first discuss how distributed systems work.
#
# The goal of this notebook is to explain the building blocks for any distributed system, and specifically a peer-to-peer system. P2P environment is a network where peers are connected, exchange information and run applications on top of it.
#
# The goals are as follows:
# - We will build a system block by block.
# - Distributed systems are hard as there are many random errors: race conditions, nasty bugs, deadlocks.
# - We will simplify the world to get to the juiciest parts without leaving out the essentials.
#
#
# We will simulate the P2P environment locally to get an idea of how such systems would work and understand the design decision that developers make.
#
# To show the different tradeoffs and why developers and researchers choose specific designs, we need a way to simulate such an environment. Here we will simulate the network and message exchange via a  discrete event simulator: [SimPy](simpy.readthedocs.io/en/latest/).
#
# For the simplicity of use, you can use wrapper for SimPY implement a P2P network simulation: `p2psimpy`.
#
#
# # Simulation of P2P environments
#
# We start the notebook by introducing the backbone for such a simulation: `BaseSimulation`.
# This class represents the network of peers with their physical representations in the world, such as physical `location`, [`bandwidth`](https://en.wikipedia.org/wiki/Bandwidth_(computing)).
#
# These properties both define and restrict the capabilities of how fast you can transfer messages and how message travel through the network (which peers see the message, which channels are used).
#
#
# `BaseSimulation` consists of 3 main parameters:
#  - *Locations*
#  - *Network Topology*
#  - *Services and Message Processors*
#
# We will explain them one by one.

# %% [markdown]
# ### Simulating latencies between locations
#
# The simulator simulates connection delays (`latency`) between the nodes in the physical space (`location`).
# This is a very rough representation of reality but is sufficient for us. You can read more about jitter and latency [here](https://www.tpx.com/blog/latency-jitter-and-packet-loss/) or [here](https://www.youtube.com/watch?v=WdbJdUh6W08).
#
#
#
# Locations are defined as a `Config` class. Variables can be constant, or probabilistic (with a probability distribution using scipy).
# This class can be used as generators of parameters, saved and loaded as a [YAML](https://en.wikipedia.org/wiki/YAML) file.

# %% [markdown]
# Location configuration should contain at least two fields: `locations` and `latencies`.
# - `locations` is an array or a tuple with names of locations.
# - `latencies` is a dictionary (matrix) with latencies of pairwise connections.
#
# Depending on the experiments, latencies can be constant, but a more realistic model is a probabilistic distribution.
# Such a distribution is represented with the `Dist` class.
#
# `Dist` class is a wrap-around [scipy.stats](https://docs.scipy.org/doc/scipy/reference/stats.html), which has a rich collection of distributions. Use the [link](https://docs.scipy.org/doc/scipy/reference/stats.html) as reference documentation when choosing a distribution function.
#
# Finally,  `Config.get()` samples all the parameters from distributions and returns them as a dictionary.
#
# Let's try it out:

# %%
from p2psimpy.config import *


class ConstLocations(Config):
    '''A configuration with 2 locations: LocA and LocB with constant latencies.'''
    locations = ['LocA', 'LocB']
    latencies = {
        'LocA': {'LocB': 12, 'LocA': 2},
        'LocB': {'LocB': 2}
    }    

class DistLocations(Config):
    '''A configuration with 2 locations: LocA and LocB with variable latencies defined with a statistical function.'''
    locations = ['LocA', 'LocB']
    latencies = {
        'LocB': {'LocB': Dist('gamma', (3, 3, 3))}, 
        'LocA': {'LocB': Dist('norm', (12, 2)), 'LocA': Dist('norm', (3, 0.5))}, 
    }    
    #nikos, changed locations to check different position distributions etc.!

# %%
ConstLocations.get()
# Out:
# {'latencies': {'LocA': {'LocB': 12, 'LocA': 2}, 'LocB': {'LocB': 2}},
#  'locations': ['LocA', 'LocB']}

# %%
DistLocations.get()
# Out:
# {'latencies': {'LocB': {'LocB': 5.442037020552996},
#   'LocA': {'LocB': 14.055149557235517, 'LocA': 3.436484328059985}},
#  'locations': ['LocA', 'LocB']}

# %% [markdown]
# Every time you call `Config.get()` it will return new sample

# %%
DistLocations.get()
#Config.get()
# Out:
# {'latencies': {'LocB': {'LocB': 12.214083826150311},
#   'LocA': {'LocB': 11.195804115734031, 'LocA': 2.571187060515547}},
#  'locations': ['LocA', 'LocB']}

# %% [markdown]
# To visualize it we can represent latencies sample as pandas dataframe. It provides a readable table:

# %%
import pandas as pd 

lat_sample = pd.DataFrame(DistLocations.get()['latencies'])
lat_sample
#ni
# Out:
#            LocB       LocA
# LocB  14.527178  11.845228
# LocA        NaN   3.638983

# %% [markdown]
# *Notice that table has **NaN** values. They will not be automatically filled with symmetric value if not specified.*
#
# We can transform the table to fill them up symmetrically.

# %%
lat_sample[pd.isnull(lat_sample)] = lat_sample.T[pd.isnull(lat_sample)]
lat_sample
# Out:
#            LocB       LocA
# LocB  14.527178  11.845228
# LocA  11.845228   3.638983

# %% [markdown]
# ### Visualizing the data
#
#
#  1. Prepare data:
#   - Trasfer to pandas dataframe
#   - Fill null values with the symmetic counter-part
#   - Transform into list of tuples: 'from', 'to', 'value'
#
#  2. Get 100 samples from the configuration with latencies
#
#  3. Visualize in a grid of histograms

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')
# 1. Data prepare
def prepare(x):
    x = pd.DataFrame(x)
    x[pd.isnull(x)] = x.T[pd.isnull(x)]
    return x.stack().reset_index()\
                    .rename(columns={'level_0':'from', 'level_1':'to', 0: 'value'})
                
# 2. Get 100 samples
df = pd.concat(prepare(DistLocations.get()['latencies']) for _ in range(100))
print(df)
# 3. Visualize in a grid of histograms
g = sns.FacetGrid(df, col='to', row='from', height=3, aspect=2)
g = g.map(sns.distplot, 'value')
print(g)

import matplotlib.pyplot as plt #nikos, please add these two lines for the code to run properly in the tutorial
plt.show() #nikos, Plots created using seaborn needed to be displayed like ordinary matplotlib plots
# Out:
#     from    to      value
# 0   LocB  LocB  15.844376
# 1   LocB  LocA   9.971062
# 2   LocA  LocB   9.971062
# 3   LocA  LocA   2.990898
# 0   LocB  LocB   9.896416
# ..   ...   ...        ...
# 3   LocA  LocA   3.168313
# 0   LocB  LocB   9.566922
# 1   LocB  LocA  12.482070
# 2   LocA  LocB  12.482070
# 3   LocA  LocA   3.382827
#
# [400 rows x 3 columns]
# <seaborn.axisgrid.FacetGrid object at 0x7f4896fe80a0>

# %% [markdown]
# The visulations shows the latency matrix for our two locations.

# %% [markdown]
# ----
# ## Peers and Topologies
#
# Usually when designing your own system, the architect should think about the network topology: *How are peers connected to each other?*.
#
#
# Simulation can work in two modes:
#
# 1. **NetworkX**. You know what topology you want to simulate, pass a network topology to the simulation.
#
# 2. **Emergent**. Peers connect to each other without a pre-defined topology. A certain topology emerges through local rules, for example, peers connect with each other through the bootstrap peers and exchange data with each other. Typically, unstructured topologies of a peer-to-peer network fall in this category. You can read more [here](https://en.wikipedia.org/wiki/Bootstrapping_node), or  read how [Bitcoin network](https://en.bitcoin.it/wiki/Network) is formed.
#
#
# ### Networkx topology
#
# Let's first see how we can form a network topology.

# %%
import networkx as nx

peer_num = 20 

# Generate a random network network topology 
G = nx.erdos_renyi_graph(20, 0.85) 

# Assign a peer type to the peers with a type. Type if later used to tell which services to run.
nx.set_node_attributes(G, {k: 'basic' for k in G.nodes()}, 'type')

sns.set(style='dark')
nx.draw_networkx(G)
#nikos,first tried with 10 nodes and 0.5 edge creation probability, 
#then increased the number of peers to 20 and increased the probability of edge creation to 0.85 to evaluate a better connected graph

# %% [markdown]
# NetworkX is a library with rich semantics to work with graphs. You can read more [here](https://networkx.github.io/documentation/stable/reference/generators.html).
#
# You can choose any graph, generate them and put `type` as node attributes. `type` is a name for the peer type. We will explain later on how it will be used in a simulation.
#
#
#
# ### Emergent topology
#
# What if topology is not known?
#
# In this case we can model the peer discovery mechanism through *bootstrapping* peers. The general bootstrap process is the following:
# 1. Bootstrap nodes are first created and introduced to the network. The goal of bootstrap nodes is to maintain list of peers and connect them with each other upon request. Bootstrap nodes are usually known in advance, for example, hardcoded in the supplied code.
# 2. The bootstrap procedure is as follows: a) new peer joins the network, b) peer sends a `Hello` message to one of bootstrap nodes, c) a bootstrap node responds to the peer with a random sample of known online peers.
# 3. The peer connect with other peers from the given sample list.
#
#
# To run default bootstrap you should pass as a parameter `topology`, a dictionary with type `peer_id` -> {`type`: type_name}
# This is all abstracted in simulation, but you can specify your own bootstrap logic later.
#
#
# <!-- ### Explain more
#
# Discovery  -->

# %% [markdown]
# -------
# ## Peer types and services
#
# Finally, our simulation needs messages and service to process these messages. In `p2psimpy` we model it through Manager Classes and `PeerType`.
#
# Below we show an example of a simple map with one type of the peer: `basic`:
#
# - Peer is described with a `PeerType(PeerConfig, services)`.
#     - `PeerConfig` describes a physical capacities of the node: bandwidth for the messages that go through (upload and download) and location (one the specified before)
#     - `services` is a list of service that peer should run. There some standard services that you can use in your simulation. But you will also implement your own later!
# - Minimally peer should have at least a connection service to connect to the network and respond to the introduction messages. These are the standard connection services available for you:
#   - `BaseConnectionManager`: a simple connection service that can connect, ping other peers and disconnect unresponsive peers. This is the recommended service for a **Networkx** topology approach.
#   - `P2PConnectionManager`: an extended BaseConnectionManger that additionally keeps the number of connections between specified `min_peers` and `max_peers`. If the number of local connections is lower than `min_peers`, service will actievly pool and ask other peers for new connection. If the number of local connections is higher than `max_peers`, service will refuse all new connection and disconnect the slowest peers. This is a recommended service for an **Emergent** topology approach.
#
# Let's see how it looks in code:

# %%
from p2psimpy.config import *
from p2psimpy.consts import *
    
class PeerConfig(Config):
    # Location of the peer - random location from the locations specified earlier 
    location = Dist('sample', DistLocations.locations)
    # Bandwidth is normally distributed with average of 50 and var 10 Mbit
    bandwidth_ul = Dist( 'norm', (25*MBit, 5*MBit))
    bandwidth_dl = Dist( 'norm', (25*MBit, 5*MBit))

# Let's add ConnectionManager - that will periodically ping neighbours and check if they are online.
# We use BaseConnectionManager - that will periodically ping peer and disconnect unresponsive peers.
from p2psimpy.services.connection_manager import BaseConnectionManager

services = (BaseConnectionManager,)
# We have on peer role: basic
peer_types = {'basic': PeerType(PeerConfig, services)}

# %% [markdown]
# How to use these configurations? Configs are used to get value.
# They work as generators and attribute descriptors.

# %% [markdown]
# ----

# %% [markdown]
# # Putting it all together
#
#
# Let's combine all you learned so far to run a simple simulation:
#
# 1. Define locations and simulation world parameters.
# 2. Define topology and number of peers with their types.
# 3. Define what each peer type is with a `PeerConfig` and what it does with services.
#
#
# After we defined all this we can create a simulation object and run it with `.run(time)`.
#
# Simulation has it's internal clock and scheduler for all events. The parameter `time` is a time until which the simulation is run.
#
#
# ***The time is defined in milliseconds**!

# %% [markdown]
# ## Random given topology
#
# Let us first try out with a random given topology generated as a networkx graph

# %%
from p2psimpy.config import *
from p2psimpy.consts import *
import networkx as nx

class Locations(Config):
    locations = ['LocA', 'LocB']
    latencies = {
        'LocB': {'LocB': Dist('gamma', (3, 3, 3))},
        'LocA': {'LocB': Dist('norm', (10, 2)), 'LocA': Dist('norm', (10, 0.5))},
    } 

# Number of nodes
N = 20
    
# Generate network topology 
G = nx.erdos_renyi_graph(N, 0.85)
# Assign a peer type to the peers 
nx.set_node_attributes(G, {k: 'basic' for k in G.nodes()}, 'type')

class PeerConfig(Config):
    location = Dist('sample', Locations.locations)
    bandwidth_ul = Dist( 'norm', (50*MBit, 10*MBit))
    bandwidth_dl = Dist( 'norm', (50*MBit, 10*MBit))

# Let's add ConnectionManager - that will periodically ping neighbours and check if they are online 
from p2psimpy.services.connection_manager import BaseConnectionManager
# For each service you can define own configuration, or use default values.   
# Lets use base connection manager - that will periodically ping peer and disconnect unresponsive peers.

services = (BaseConnectionManager,)
peer_types = {'basic': PeerType(PeerConfig, services)}

# Display the topology 
nx.draw_networkx(G)

# %%
from p2psimpy.simulation import BaseSimulation

# Create BaseSimulation with enabled logger and save in the logs directory. 
sim = BaseSimulation(Locations, G, peer_types, enable_logger=True, logger_dir='logs')

# Let's run the simulation for 5 seconds
sim.run(5_000)

# %% [markdown]
# ----------------------------
#
# What's next? There is no output.
#
# We run the simulator with logger enabled to see the all the messages exchanged in the network.
#
# The output is written to the logs in `\logs` directory. Let's see what is the output.
# Each peer writes its own log with events happening like received message, connecting to a peer etc.
#
# For example, here is the log of peer 1:

# %%
with open('logs/Peer_1:basic.log') as s:
    print(s.read())
# Out:
# Peer_1:basic INFO 2.283320815548501: Received message <Hello:> from Peer_19:basic
# Peer_1:basic INFO 2.283320815548501: Connecting to Peer_19:basic
# Peer_1:basic INFO 2.283320815548501: Sending message <Hello:> to Peer_19:basic
# Peer_1:basic INFO 3.6469137691069258: Received message <Hello:> from Peer_5:basic
# Peer_1:basic INFO 3.6469137691069258: Connecting to Peer_5:basic
# Peer_1:basic INFO 3.6469137691069258: Sending message <Hello:> to Peer_5:basic
# Peer_1:basic INFO 3.7293396448358562: Connecting to Peer_7:basic
# Peer_1:basic INFO 3.8256617368000345: Connecting to Peer_10:basic
# Peer_1:basic INFO 3.9770299722925198: Received message <Hello:> from Peer_2:basic
# Peer_1:basic INFO 3.9770299722925198: Connecting to Peer_2:basic
# Peer_1:basic INFO 3.9770299722925198: Sending message <Hello:> to Peer_2:basic
# Peer_1:basic INFO 4.229402826277072: Received message <Hello:> from Peer_4:basic
# Peer_1:basic INFO 4.229402826277072: Connecting to Peer_4:basic
# Peer_1:basic INFO 4.229402826277072: Sending message <Hello:> to Peer_4:basic
# Peer_1:basic INFO 4.358882042231699: Received message <Hello:> from Peer_8:basic
# Peer_1:basic INFO 4.358882042231699: Connecting to Peer_8:basic
# Peer_1:basic INFO 4.358882042231699: Sending message <Hello:> to Peer_8:basic
# Peer_1:basic INFO 4.752338871184605: Connecting to Peer_15:basic
# Peer_1:basic INFO 4.756122900871509: Connecting to Peer_11:basic
# Peer_1:basic INFO 4.826198756456491: Received message <Hello:> from Peer_9:basic
# Peer_1:basic INFO 4.826198756456491: Connecting to Peer_9:basic
# Peer_1:basic INFO 4.826198756456491: Sending message <Hello:> to Peer_9:basic
# Peer_1:basic INFO 4.922090543442391: Connecting to Peer_2:basic
# Peer_1:basic INFO 4.967184225898157: Received message <Hello:> from Peer_6:basic
# Peer_1:basic INFO 4.967184225898157: Connecting to Peer_6:basic
# Peer_1:basic INFO 4.967184225898157: Sending message <Hello:> to Peer_6:basic
# Peer_1:basic INFO 5.146245367271861: Received message <Hello:> from Peer_12:basic
# Peer_1:basic INFO 5.146245367271861: Connecting to Peer_12:basic
# Peer_1:basic INFO 5.146245367271861: Sending message <Hello:> to Peer_12:basic
# Peer_1:basic INFO 6.159335797451049: Received message <Hello:> from Peer_3:basic
# Peer_1:basic INFO 6.159335797451049: Connecting to Peer_3:basic
# Peer_1:basic INFO 6.159335797451049: Sending message <Hello:> to Peer_3:basic
# Peer_1:basic INFO 6.693626379821816: Received message <Hello:> from Peer_10:basic
# Peer_1:basic INFO 6.975045883641153: Connecting to Peer_17:basic
# Peer_1:basic INFO 7.213596152864365: Received message <Hello:> from Peer_11:basic
# Peer_1:basic INFO 7.7014091691527105: Received message <Hello:> from Peer_13:basic
# Peer_1:basic INFO 7.7014091691527105: Connecting to Peer_13:basic
# Peer_1:basic INFO 7.7014091691527105: Sending message <Hello:> to Peer_13:basic
# Peer_1:basic INFO 8.328279399055296: Received message <Hello:> from Peer_7:basic
# Peer_1:basic INFO 8.787434729592276: Received message <Hello:> from Peer_10:basic
# Peer_1:basic INFO 8.847200070674816: Received message <Hello:> from Peer_17:basic
# Peer_1:basic INFO 9.107481377350524: Received message <Hello:> from Peer_11:basic
# Peer_1:basic INFO 10.33554176138574: Received message <Hello:> from Peer_15:basic
# Peer_1:basic INFO 11.691493664915269: Received message <Hello:> from Peer_7:basic
# Peer_1:basic INFO 12.796124669477132: Received message <Hello:> from Peer_17:basic
# Peer_1:basic INFO 13.058271753510754: Received message <Hello:> from Peer_2:basic
# Peer_1:basic INFO 15.624470091047861: Received message <Hello:> from Peer_2:basic
# Peer_1:basic INFO 26.070387973109618: Received message <Hello:> from Peer_15:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_19:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_5:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_7:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_10:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_4:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_8:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_15:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_11:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_9:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_6:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_12:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_3:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_17:basic
# Peer_1:basic INFO 1000: Sending message <Ping:> to Peer_13:basic
# Peer_1:basic INFO 1002.2591773224012: Received message <Ping:> from Peer_3:basic
# Peer_1:basic INFO 1002.2591773224012: Sending message <Pong:> to Peer_3:basic
# Peer_1:basic INFO 1003.1736278543586: Received message <Ping:> from Peer_9:basic
# Peer_1:basic INFO 1003.1736278543586: Sending message <Pong:> to Peer_9:basic
# Peer_1:basic INFO 1003.2048790209375: Received message <Ping:> from Peer_8:basic
# Peer_1:basic INFO 1003.2048790209375: Sending message <Pong:> to Peer_8:basic
# Peer_1:basic INFO 1003.529611360182: Received message <Ping:> from Peer_12:basic
# Peer_1:basic INFO 1003.529611360182: Sending message <Pong:> to Peer_12:basic
# Peer_1:basic INFO 1004.0278349592664: Received message <Ping:> from Peer_17:basic
# Peer_1:basic INFO 1004.0278349592664: Sending message <Pong:> to Peer_17:basic
# Peer_1:basic INFO 1004.5859422009844: Received message <Ping:> from Peer_6:basic
# Peer_1:basic INFO 1004.5859422009844: Sending message <Pong:> to Peer_6:basic
# Peer_1:basic INFO 1004.7474912513626: Received message <Ping:> from Peer_11:basic
# Peer_1:basic INFO 1004.7474912513626: Sending message <Pong:> to Peer_11:basic
# Peer_1:basic INFO 1004.8176598377632: Received message <Ping:> from Peer_10:basic
# Peer_1:basic INFO 1004.8176598377632: Sending message <Pong:> to Peer_10:basic
# Peer_1:basic INFO 1005.2701339995145: Received message <Ping:> from Peer_19:basic
# Peer_1:basic INFO 1005.2701339995145: Sending message <Pong:> to Peer_19:basic
# Peer_1:basic INFO 1005.7234743762568: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 1005.7234743762568: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 1005.7297569833805: Received message <Ping:> from Peer_7:basic
# Peer_1:basic INFO 1005.7297569833805: Sending message <Pong:> to Peer_7:basic
# Peer_1:basic INFO 1005.797256023658: Received message <Ping:> from Peer_4:basic
# Peer_1:basic INFO 1005.797256023658: Sending message <Pong:> to Peer_4:basic
# Peer_1:basic INFO 1006.1807170426009: Received message <Pong:> from Peer_3:basic
# Peer_1:basic INFO 1006.7574050015764: Received message <Ping:> from Peer_13:basic
# Peer_1:basic INFO 1006.7574050015764: Sending message <Pong:> to Peer_13:basic
# Peer_1:basic INFO 1007.4826947604629: Received message <Ping:> from Peer_5:basic
# Peer_1:basic INFO 1007.4826947604629: Sending message <Pong:> to Peer_5:basic
# Peer_1:basic INFO 1007.6599766029074: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 1007.6599766029074: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 1007.8262019852132: Received message <Pong:> from Peer_12:basic
# Peer_1:basic INFO 1008.7176868888886: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 1009.7217501343822: Received message <Pong:> from Peer_19:basic
# Peer_1:basic INFO 1009.9388522621932: Received message <Pong:> from Peer_8:basic
# Peer_1:basic INFO 1010.0579666668887: Received message <Pong:> from Peer_7:basic
# Peer_1:basic INFO 1010.4011951390229: Received message <Pong:> from Peer_17:basic
# Peer_1:basic INFO 1011.1749960197726: Received message <Pong:> from Peer_6:basic
# Peer_1:basic INFO 1011.3509257627508: Received message <Pong:> from Peer_5:basic
# Peer_1:basic INFO 1011.9669487041043: Received message <Pong:> from Peer_13:basic
# Peer_1:basic INFO 1012.3506603873575: Received message <Pong:> from Peer_4:basic
# Peer_1:basic INFO 1012.3514344842187: Received message <Pong:> from Peer_9:basic
# Peer_1:basic INFO 1012.4138735649568: Received message <Pong:> from Peer_10:basic
# Peer_1:basic INFO 1013.1005193238096: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 1014.1136270056057: Received message <Pong:> from Peer_11:basic
# Peer_1:basic INFO 1014.6699398749719: Received message <Ping:> from Peer_15:basic
# Peer_1:basic INFO 1014.6699398749719: Sending message <Pong:> to Peer_15:basic
# Peer_1:basic INFO 1014.7579292789418: Received message <Pong:> from Peer_15:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_19:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_5:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_7:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_10:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_4:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_8:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_15:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_11:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_9:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_6:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_12:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_3:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_17:basic
# Peer_1:basic INFO 2000: Sending message <Ping:> to Peer_13:basic
# Peer_1:basic INFO 2003.416325637894: Received message <Ping:> from Peer_11:basic
# Peer_1:basic INFO 2003.416325637894: Sending message <Pong:> to Peer_11:basic
# Peer_1:basic INFO 2003.73429828032: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 2003.73429828032: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 2003.9964029459206: Received message <Ping:> from Peer_4:basic
# Peer_1:basic INFO 2003.9964029459206: Sending message <Pong:> to Peer_4:basic
# Peer_1:basic INFO 2004.3899305939358: Received message <Ping:> from Peer_15:basic
# Peer_1:basic INFO 2004.3899305939358: Sending message <Pong:> to Peer_15:basic
# Peer_1:basic INFO 2005.3207277182792: Received message <Ping:> from Peer_13:basic
# Peer_1:basic INFO 2005.3207277182792: Sending message <Pong:> to Peer_13:basic
# Peer_1:basic INFO 2005.3345869862665: Received message <Ping:> from Peer_5:basic
# Peer_1:basic INFO 2005.3345869862665: Sending message <Pong:> to Peer_5:basic
# Peer_1:basic INFO 2005.4368772338466: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 2005.4368772338466: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 2005.5202907064331: Received message <Ping:> from Peer_10:basic
# Peer_1:basic INFO 2005.5202907064331: Sending message <Pong:> to Peer_10:basic
# Peer_1:basic INFO 2005.5339684714088: Received message <Ping:> from Peer_8:basic
# Peer_1:basic INFO 2005.5339684714088: Sending message <Pong:> to Peer_8:basic
# Peer_1:basic INFO 2005.8165194023243: Received message <Ping:> from Peer_6:basic
# Peer_1:basic INFO 2005.8165194023243: Sending message <Pong:> to Peer_6:basic
# Peer_1:basic INFO 2005.8950740534563: Received message <Ping:> from Peer_19:basic
# Peer_1:basic INFO 2005.8950740534563: Sending message <Pong:> to Peer_19:basic
# Peer_1:basic INFO 2006.1187043530256: Received message <Ping:> from Peer_7:basic
# Peer_1:basic INFO 2006.1187043530256: Sending message <Pong:> to Peer_7:basic
# Peer_1:basic INFO 2006.4205181578577: Received message <Ping:> from Peer_17:basic
# Peer_1:basic INFO 2006.4205181578577: Sending message <Pong:> to Peer_17:basic
# Peer_1:basic INFO 2006.5268374414559: Received message <Ping:> from Peer_9:basic
# Peer_1:basic INFO 2006.5268374414559: Sending message <Pong:> to Peer_9:basic
# Peer_1:basic INFO 2006.6364685867445: Received message <Ping:> from Peer_12:basic
# Peer_1:basic INFO 2006.6364685867445: Sending message <Pong:> to Peer_12:basic
# Peer_1:basic INFO 2007.46653781807: Received message <Pong:> from Peer_8:basic
# Peer_1:basic INFO 2007.6269832311177: Received message <Pong:> from Peer_6:basic
# Peer_1:basic INFO 2007.6922034784568: Received message <Pong:> from Peer_13:basic
# Peer_1:basic INFO 2007.7572384887187: Received message <Ping:> from Peer_3:basic
# Peer_1:basic INFO 2007.7572384887187: Sending message <Pong:> to Peer_3:basic
# Peer_1:basic INFO 2007.907082992629: Received message <Pong:> from Peer_5:basic
# Peer_1:basic INFO 2009.2033891297503: Received message <Pong:> from Peer_4:basic
# Peer_1:basic INFO 2009.2122932086054: Received message <Pong:> from Peer_12:basic
# Peer_1:basic INFO 2009.9247439308263: Received message <Pong:> from Peer_15:basic
# Peer_1:basic INFO 2010.4047598439126: Received message <Pong:> from Peer_11:basic
# Peer_1:basic INFO 2010.659686633926: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 2010.674888537949: Received message <Pong:> from Peer_3:basic
# Peer_1:basic INFO 2010.9453663421323: Received message <Pong:> from Peer_7:basic
# Peer_1:basic INFO 2011.2814828699575: Received message <Pong:> from Peer_10:basic
# Peer_1:basic INFO 2011.3276756957284: Received message <Pong:> from Peer_19:basic
# Peer_1:basic INFO 2012.2167773477747: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 2018.6626418925307: Received message <Pong:> from Peer_9:basic
# Peer_1:basic INFO 2020.7325862149482: Received message <Pong:> from Peer_17:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_19:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_5:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_7:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_10:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_4:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_8:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_15:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_11:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_9:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_6:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_12:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_3:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_17:basic
# Peer_1:basic INFO 3000: Sending message <Ping:> to Peer_13:basic
# Peer_1:basic INFO 3003.5892347735935: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 3003.5892347735935: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 3003.772605817616: Received message <Ping:> from Peer_5:basic
# Peer_1:basic INFO 3003.772605817616: Sending message <Pong:> to Peer_5:basic
# Peer_1:basic INFO 3003.925110242885: Received message <Ping:> from Peer_4:basic
# Peer_1:basic INFO 3003.925110242885: Sending message <Pong:> to Peer_4:basic
# Peer_1:basic INFO 3004.035652316181: Received message <Ping:> from Peer_17:basic
# Peer_1:basic INFO 3004.035652316181: Sending message <Pong:> to Peer_17:basic
# Peer_1:basic INFO 3004.7378536568654: Received message <Ping:> from Peer_12:basic
# Peer_1:basic INFO 3004.7378536568654: Sending message <Pong:> to Peer_12:basic
# Peer_1:basic INFO 3004.981522879664: Received message <Ping:> from Peer_6:basic
# Peer_1:basic INFO 3004.981522879664: Sending message <Pong:> to Peer_6:basic
# Peer_1:basic INFO 3005.173021151465: Received message <Ping:> from Peer_11:basic
# Peer_1:basic INFO 3005.173021151465: Sending message <Pong:> to Peer_11:basic
# Peer_1:basic INFO 3005.549285960493: Received message <Ping:> from Peer_19:basic
# Peer_1:basic INFO 3005.549285960493: Sending message <Pong:> to Peer_19:basic
# Peer_1:basic INFO 3006.047627739216: Received message <Ping:> from Peer_8:basic
# Peer_1:basic INFO 3006.047627739216: Sending message <Pong:> to Peer_8:basic
# Peer_1:basic INFO 3006.3881809072745: Received message <Ping:> from Peer_13:basic
# Peer_1:basic INFO 3006.3881809072745: Sending message <Pong:> to Peer_13:basic
# Peer_1:basic INFO 3006.6908570638493: Received message <Ping:> from Peer_10:basic
# Peer_1:basic INFO 3006.6908570638493: Sending message <Pong:> to Peer_10:basic
# Peer_1:basic INFO 3006.9692860072746: Received message <Ping:> from Peer_9:basic
# Peer_1:basic INFO 3006.9692860072746: Sending message <Pong:> to Peer_9:basic
# Peer_1:basic INFO 3007.124736077707: Received message <Ping:> from Peer_15:basic
# Peer_1:basic INFO 3007.124736077707: Sending message <Pong:> to Peer_15:basic
# Peer_1:basic INFO 3008.078037189548: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 3008.078037189548: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 3008.2918323198533: Received message <Pong:> from Peer_5:basic
# Peer_1:basic INFO 3008.4940511132095: Received message <Pong:> from Peer_9:basic
# Peer_1:basic INFO 3008.6192222646005: Received message <Ping:> from Peer_7:basic
# Peer_1:basic INFO 3008.6192222646005: Sending message <Pong:> to Peer_7:basic
# Peer_1:basic INFO 3009.064347752607: Received message <Pong:> from Peer_8:basic
# Peer_1:basic INFO 3009.1703271894958: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 3009.17752235039: Received message <Pong:> from Peer_4:basic
# Peer_1:basic INFO 3010.0447662130446: Received message <Pong:> from Peer_12:basic
# Peer_1:basic INFO 3010.4421611679286: Received message <Pong:> from Peer_6:basic
# Peer_1:basic INFO 3010.6694017480263: Received message <Pong:> from Peer_10:basic
# Peer_1:basic INFO 3011.5144549913666: Received message <Pong:> from Peer_15:basic
# Peer_1:basic INFO 3011.542894927567: Received message <Pong:> from Peer_13:basic
# Peer_1:basic INFO 3012.0026889008004: Received message <Pong:> from Peer_3:basic
# Peer_1:basic INFO 3012.0911242977386: Received message <Pong:> from Peer_17:basic
# Peer_1:basic INFO 3012.1353661226167: Received message <Pong:> from Peer_11:basic
# Peer_1:basic INFO 3012.2323092311854: Received message <Pong:> from Peer_19:basic
# Peer_1:basic INFO 3013.350682367399: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 3013.5057563662726: Received message <Ping:> from Peer_3:basic
# Peer_1:basic INFO 3013.5057563662726: Sending message <Pong:> to Peer_3:basic
# Peer_1:basic INFO 3019.895343920723: Received message <Pong:> from Peer_7:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_19:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_5:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_7:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_10:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_4:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_8:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_15:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_11:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_9:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_2:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_6:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_12:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_3:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_17:basic
# Peer_1:basic INFO 4000: Sending message <Ping:> to Peer_13:basic
# Peer_1:basic INFO 4002.295317740584: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 4002.295317740584: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 4002.823748195756: Received message <Ping:> from Peer_11:basic
# Peer_1:basic INFO 4002.823748195756: Sending message <Pong:> to Peer_11:basic
# Peer_1:basic INFO 4002.9247184691994: Received message <Ping:> from Peer_8:basic
# Peer_1:basic INFO 4002.9247184691994: Sending message <Pong:> to Peer_8:basic
# Peer_1:basic INFO 4003.8431135218825: Received message <Ping:> from Peer_6:basic
# Peer_1:basic INFO 4003.8431135218825: Sending message <Pong:> to Peer_6:basic
# Peer_1:basic INFO 4003.9382695982595: Received message <Ping:> from Peer_5:basic
# Peer_1:basic INFO 4003.9382695982595: Sending message <Pong:> to Peer_5:basic
# Peer_1:basic INFO 4003.9382749254473: Received message <Ping:> from Peer_10:basic
# Peer_1:basic INFO 4003.9382749254473: Sending message <Pong:> to Peer_10:basic
# Peer_1:basic INFO 4004.6514332208503: Received message <Ping:> from Peer_12:basic
# Peer_1:basic INFO 4004.6514332208503: Sending message <Pong:> to Peer_12:basic
# Peer_1:basic INFO 4004.684457080569: Received message <Ping:> from Peer_19:basic
# Peer_1:basic INFO 4004.684457080569: Sending message <Pong:> to Peer_19:basic
# Peer_1:basic INFO 4005.07593851978: Received message <Ping:> from Peer_9:basic
# Peer_1:basic INFO 4005.07593851978: Sending message <Pong:> to Peer_9:basic
# Peer_1:basic INFO 4005.1123613482982: Received message <Ping:> from Peer_7:basic
# Peer_1:basic INFO 4005.1123613482982: Sending message <Pong:> to Peer_7:basic
# Peer_1:basic INFO 4005.1658370706295: Received message <Ping:> from Peer_3:basic
# Peer_1:basic INFO 4005.1658370706295: Sending message <Pong:> to Peer_3:basic
# Peer_1:basic INFO 4005.6460988286003: Received message <Ping:> from Peer_17:basic
# Peer_1:basic INFO 4005.6460988286003: Sending message <Pong:> to Peer_17:basic
# Peer_1:basic INFO 4006.0545308425926: Received message <Ping:> from Peer_13:basic
# Peer_1:basic INFO 4006.0545308425926: Sending message <Pong:> to Peer_13:basic
# Peer_1:basic INFO 4006.19279196982: Received message <Ping:> from Peer_2:basic
# Peer_1:basic INFO 4006.19279196982: Sending message <Pong:> to Peer_2:basic
# Peer_1:basic INFO 4006.4363643544452: Received message <Ping:> from Peer_4:basic
# Peer_1:basic INFO 4006.4363643544452: Sending message <Pong:> to Peer_4:basic
# Peer_1:basic INFO 4006.7328804329873: Received message <Pong:> from Peer_13:basic
# Peer_1:basic INFO 4007.0911646615505: Received message <Pong:> from Peer_9:basic
# Peer_1:basic INFO 4007.1160875160995: Received message <Pong:> from Peer_12:basic
# Peer_1:basic INFO 4008.23407180086: Received message <Pong:> from Peer_10:basic
# Peer_1:basic INFO 4008.2866274292865: Received message <Pong:> from Peer_4:basic
# Peer_1:basic INFO 4008.7775168334533: Received message <Ping:> from Peer_15:basic
# Peer_1:basic INFO 4008.7775168334533: Sending message <Pong:> to Peer_15:basic
# Peer_1:basic INFO 4008.844721495804: Received message <Pong:> from Peer_15:basic
# Peer_1:basic INFO 4008.88109531111: Received message <Pong:> from Peer_8:basic
# Peer_1:basic INFO 4009.0419058072644: Received message <Pong:> from Peer_5:basic
# Peer_1:basic INFO 4009.9258933113697: Received message <Pong:> from Peer_6:basic
# Peer_1:basic INFO 4010.3874270515857: Received message <Pong:> from Peer_3:basic
# Peer_1:basic INFO 4010.62222155488: Received message <Pong:> from Peer_11:basic
# Peer_1:basic INFO 4010.7253579067547: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 4011.036235258194: Received message <Pong:> from Peer_2:basic
# Peer_1:basic INFO 4011.396195311465: Received message <Pong:> from Peer_19:basic
# Peer_1:basic INFO 4012.7320521060183: Received message <Pong:> from Peer_17:basic
# Peer_1:basic INFO 4017.2861336020387: Received message <Pong:> from Peer_7:basic

# %% [markdown]
# ## Emergent topology
#
# Now let's try an emergent topology, we will use the same configuration, but use bootstrap peer for discovery and building a network. For the connection manager we will use `P2PConnectionManager`.

# %%
from p2psimpy.services.connection_manager import P2PConnectionManager

num_peers = 20

topology_specs = {i:{'type': 'basic'} for i in range(1, num_peers+1)}

class ConnectionConfig(Config):
    min_peers = 8
    max_peers = 16

peer_types = {'basic': PeerType(PeerConfig, {P2PConnectionManager: ConnectionConfig})}
#nikos, changed it accordingly to accomodate 20 nodes

# %%
sim = BaseSimulation(Locations, topology_specs, peer_types, logger_dir='logs2')

# Let's run the simulation for 5 seconds
sim.run(10_000)
#nikos, changed it to 10 seconds to evaluate the phenomenon further

# %% [markdown]
# #### The peers form themselves a random topology

# %%
G1 = sim.get_graph()
nx.draw_networkx(G1)

# %%
with open('logs2/Peer_1:basic.log') as s:
    print(s.read())
# Out:
# Peer_1:basic WARNING 0: Not enough peers, fetching more (0, 8)
# Peer_1:basic INFO 5.332926134352314: Connecting to Peer_21:bootstrap
# Peer_1:basic INFO 10.539684777659353: Received message <RequestPeers:> from Peer_21:bootstrap
# Peer_1:basic INFO 10.539684777659353: Sending message <PeerList> to Peer_21:bootstrap
# Peer_1:basic INFO 10.546781365308924: Received message <Hello:> from Peer_21:bootstrap
# Peer_1:basic WARNING 500: Not enough peers, fetching more (1, 8)
# Peer_1:basic INFO 500: Sending message <RequestPeers:> to Peer_21:bootstrap
# Peer_1:basic INFO 507.1625020072709: Received message <PeerList> from Peer_21:bootstrap
# Peer_1:basic WARNING 1000: Not enough peers, fetching more (1, 8)
# Peer_1:basic INFO 1000: Sending message <RequestPeers:> to Peer_21:bootstrap
# Peer_1:basic INFO 1003.0475265663421: Connecting to Peer_17:basic
# Peer_1:basic INFO 1005.1793436514447: Received message <Hello:> from Peer_5:basic
# Peer_1:basic INFO 1005.1793436514447: Connecting to Peer_5:basic
# Peer_1:basic INFO 1005.1793436514447: Sending message <Hello:> to Peer_5:basic
# Peer_1:basic INFO 1005.1793436514447: Sending message <RequestPeers:> to Peer_5:basic
# Peer_1:basic INFO 1007.422313011634: Received message <Hello:> from Peer_17:basic
# Peer_1:basic INFO 1007.9239781177107: Received message <Hello:> from Peer_14:basic
# Peer_1:basic INFO 1007.9239781177107: Connecting to Peer_14:basic
# Peer_1:basic INFO 1007.9239781177107: Sending message <Hello:> to Peer_14:basic
# Peer_1:basic INFO 1007.9239781177107: Sending message <RequestPeers:> to Peer_14:basic
# Peer_1:basic INFO 1009.0758121117566: Received message <RequestPeers:> from Peer_17:basic
# Peer_1:basic INFO 1009.0758121117566: Sending message <PeerList> to Peer_17:basic
# Peer_1:basic INFO 1012.8960751421937: Received message <PeerList> from Peer_5:basic
# Peer_1:basic INFO 1013.920926543482: Received message <PeerList> from Peer_21:bootstrap
# Peer_1:basic INFO 1021.789714331374: Received message <PeerList> from Peer_14:basic
# Peer_1:basic WARNING 1500: Not enough peers, fetching more (4, 8)
# Peer_1:basic INFO 1500: Sending message <RequestPeers:> to Peer_21:bootstrap
# Peer_1:basic INFO 1500: Sending message <RequestPeers:> to Peer_14:basic
# Peer_1:basic INFO 1500: Sending message <RequestPeers:> to Peer_17:basic
# Peer_1:basic INFO 1500: Sending message <RequestPeers:> to Peer_5:basic
# Peer_1:basic INFO 1503.697177981929: Received message <RequestPeers:> from Peer_14:basic
# Peer_1:basic INFO 1503.697177981929: Sending message <PeerList> to Peer_14:basic
# Peer_1:basic INFO 1504.4583872620947: Connecting to Peer_19:basic
# Peer_1:basic INFO 1505.306862648248: Received message <Hello:> from Peer_19:basic
# Peer_1:basic INFO 1505.5110791766317: Received message <RequestPeers:> from Peer_17:basic
# Peer_1:basic INFO 1505.5110791766317: Sending message <PeerList> to Peer_17:basic
# Peer_1:basic INFO 1507.9078000116895: Received message <RequestPeers:> from Peer_5:basic
# Peer_1:basic INFO 1507.9078000116895: Sending message <PeerList> to Peer_5:basic
# Peer_1:basic INFO 1508.7035049733358: Received message <RequestPeers:> from Peer_19:basic
# Peer_1:basic INFO 1508.7035049733358: Sending message <PeerList> to Peer_19:basic
# Peer_1:basic INFO 1509.1396855811838: Received message <PeerList> from Peer_5:basic
# Peer_1:basic INFO 1509.2759245883549: Received message <Hello:> from Peer_19:basic
# Peer_1:basic INFO 1510.4845280173151: Received message <PeerList> from Peer_17:basic
# Peer_1:basic INFO 1514.900936706326: Received message <PeerList> from Peer_14:basic
# Peer_1:basic INFO 9008.49429310544: Received message <Pong:> from Peer_14:basic
# Peer_1:basic INFO 9008.659162833721: Received message <Ping:> from Peer_14:basic
# Peer_1:basic INFO 9008.659162833721: Sending message <Pong:> to Peer_14:basic
# Peer_1:basic INFO 9009.12507812467: Received message <Pong:> from Peer_3:basic
# Peer_1:basic INFO 9009.707536781183: Received message <Pong:> from Peer_6:basic
# Peer_1:basic INFO 9009.72536942282: Received message <Pong:> from Peer_17:basic
# Peer_1:basic INFO 9012.234219535196: Received message <Pong:> from Peer_9:basic
# Peer_1:basic INFO 9500: Sending message <Ping:> to Peer_21:bootstrap
# Peer_1:basic INFO 9500: Sending message <Ping:> to Peer_5:basic
# Peer_1:basic INFO 9500: Sending message <Ping:> to Peer_19:basic
# Peer_1:basic INFO 9503.644266547815: Received message <Ping:> from Peer_19:basic
# Peer_1:basic INFO 9503.644266547815: Sending message <Pong:> to Peer_19:basic
# Peer_1:basic INFO 9504.535649239693: Received message <Ping:> from Peer_21:bootstrap
# Peer_1:basic INFO 9504.535649239693: Sending message <Pong:> to Peer_21:bootstrap
# Peer_1:basic INFO 9505.883085982403: Received message <Ping:> from Peer_5:basic
# Peer_1:basic INFO 9505.883085982403: Sending message <Pong:> to Peer_5:basic
# Peer_1:basic INFO 9506.636938757561: Received message <Pong:> from Peer_21:bootstrap
# Peer_1:basic INFO 9509.353543846983: Received message <Pong:> from Peer_5:basic
# Peer_1:basic INFO 9511.361860480816: Received message <Pong:> from Peer_19:basic

# %% [markdown]
# ------------------
#
# Now you get how to work a simulation, in the next notebook we will take a look into services and implement our own.

# %% [markdown]
# ## Your experiments here
#
#
# 1. Change the latency between the locations and look at the logs.
# 2. Change the rules for the discovery

# %%
from p2psimpy.config import *
from p2psimpy.consts import *
import networkx as nx

class Locations(Config):
    locations = ['LocA', 'LocB']
    latencies = {
        'LocB': {'LocB': Dist('gamma', (3, 3, 3))},
        'LocA': {'LocB': Dist('norm', (10, 2)), 'LocA': Dist('norm', (10, 0.5))},
    } 

# Number of nodes
N = 20
    
# Generate network topology 
G = nx.erdos_renyi_graph(N, 0.85)
# Assign a peer type to the peers 
nx.set_node_attributes(G, {k: 'basic' for k in G.nodes()}, 'type')

class PeerConfig(Config):
    location = Dist('sample', Locations.locations)
    bandwidth_ul = Dist( 'norm', (50*MBit, 10*MBit))
    bandwidth_dl = Dist( 'norm', (50*MBit, 10*MBit))

# Let's add ConnectionManager - that will periodically ping neighbours and check if they are online 
from p2psimpy.services.connection_manager import BaseConnectionManager
# For each service you can define own configuration, or use default values.   
# Lets use base connection manager - that will periodically ping peer and disconnect unresponsive peers.

services = (BaseConnectionManager,)
peer_types = {'basic': PeerType(PeerConfig, services)}

# Display the topology 
nx.draw_networkx(G)

from p2psimpy.simulation import BaseSimulation

# Create BaseSimulation with enabled logger and save in the logs directory. 
sim = BaseSimulation(Locations, G, peer_types, enable_logger=True, logger_dir='logs')

# Let's run the simulation for 5 seconds
sim.run(10_000)

# %%
with open('logs/Peer_2:basic.log') as s:
    print(s.read())
# Out:
# Peer_2:basic INFO 2.7941638827813433: Connecting to Peer_10:basic
# Peer_2:basic INFO 2.8453217351849207: Connecting to Peer_15:basic
# Peer_2:basic INFO 2.996547209562697: Connecting to Peer_8:basic
# Peer_2:basic INFO 3.2556432289330393: Connecting to Peer_8:basic
# Peer_2:basic INFO 3.271636247148982: Connecting to Peer_5:basic
# Peer_2:basic INFO 3.4007412763544917: Connecting to Peer_12:basic
# Peer_2:basic INFO 3.5930762260577493: Connecting to Peer_16:basic
# Peer_2:basic INFO 3.708075495590427: Received message <Hello:> from Peer_12:basic
# Peer_2:basic INFO 3.8103369963609355: Connecting to Peer_7:basic
# Peer_2:basic INFO 3.9373972761637317: Connecting to Peer_12:basic
# Peer_2:basic INFO 4.03349874548198: Connecting to Peer_9:basic
# Peer_2:basic INFO 4.060679349834111: Received message <Hello:> from Peer_3:basic
# Peer_2:basic INFO 4.060679349834111: Connecting to Peer_3:basic
# Peer_2:basic INFO 4.060679349834111: Sending message <Hello:> to Peer_3:basic
# Peer_2:basic INFO 4.077398806710358: Received message <Hello:> from Peer_16:basic
# Peer_2:basic INFO 4.077398806710358: Connecting to Peer_16:basic
# Peer_2:basic INFO 4.077398806710358: Sending message <Hello:> to Peer_16:basic
# Peer_2:basic INFO 4.147112700044889: Received message <Hello:> from Peer_18:basic
# Peer_2:basic INFO 4.147112700044889: Connecting to Peer_18:basic
# Peer_2:basic INFO 4.147112700044889: Sending message <Hello:> to Peer_18:basic
# Peer_2:basic INFO 4.1848154385813805: Received message <Hello:> from Peer_4:basic
# Peer_2:basic INFO 4.1848154385813805: Connecting to Peer_4:basic
# Peer_2:basic INFO 4.1848154385813805: Sending message <Hello:> to Peer_4:basic
# Peer_2:basic INFO 4.223316532171042: Connecting to Peer_13:basic
# Peer_2:basic INFO 4.260103366421731: Received message <Hello:> from Peer_8:basic
# Peer_2:basic INFO 4.311264406823173: Connecting to Peer_11:basic
# Peer_2:basic INFO 4.4160734063143465: Connecting to Peer_19:basic
# Peer_2:basic INFO 4.575500108758296: Received message <Hello:> from Peer_17:basic
# Peer_2:basic INFO 4.575500108758296: Connecting to Peer_17:basic
# Peer_2:basic INFO 4.575500108758296: Sending message <Hello:> to Peer_17:basic
# Peer_2:basic INFO 4.6893468898844795: Connecting to Peer_6:basic
# Peer_2:basic INFO 4.732384711685672: Received message <Hello:> from Peer_17:basic
# Peer_2:basic INFO 4.732384711685672: Connecting to Peer_17:basic
# Peer_2:basic INFO 4.732384711685672: Sending message <Hello:> to Peer_17:basic
# Peer_2:basic INFO 4.785371695564798: Received message <Hello:> from Peer_5:basic
# Peer_2:basic INFO 4.785371695564798: Connecting to Peer_5:basic
# Peer_2:basic INFO 4.785371695564798: Sending message <Hello:> to Peer_5:basic
# Peer_2:basic INFO 4.888795027910867: Received message <Hello:> from Peer_6:basic
# Peer_2:basic INFO 4.913776560617684: Received message <Hello:> from Peer_9:basic
# Peer_2:basic INFO 4.972091999905455: Received message <Hello:> from Peer_12:basic
# Peer_2:basic INFO 5.036496617577069: Received message <Hello:> from Peer_13:basic
# Peer_2:basic INFO 5.043233410531926: Received message <Hello:> from Peer_5:basic
# Peer_2:basic INFO 5.073622852729903: Connecting to Peer_7:basic
# Peer_2:basic INFO 5.091660124460018: Connecting to Peer_9:basic
# Peer_2:basic INFO 5.097116317795496: Received message <Hello:> from Peer_7:basic
# Peer_2:basic INFO 5.1018481654212415: Received message <Hello:> from Peer_9:basic
# Peer_2:basic INFO 5.412579758678585: Received message <Hello:> from Peer_10:basic
# Peer_2:basic INFO 5.622315429602358: Connecting to Peer_6:basic
# Peer_2:basic INFO 5.662591223996095: Connecting to Peer_18:basic
# Peer_2:basic INFO 5.912646209111861: Received message <Hello:> from Peer_10:basic
# Peer_2:basic INFO 5.912646209111861: Connecting to Peer_10:basic
# Peer_2:basic INFO 5.912646209111861: Sending message <Hello:> to Peer_10:basic
# Peer_2:basic INFO 6.01099615219644: Received message <Hello:> from Peer_7:basic
# Peer_2:basic INFO 6.1025397475125365: Received message <Hello:> from Peer_1:basic
# Peer_2:basic INFO 6.1025397475125365: Connecting to Peer_1:basic
# Peer_2:basic INFO 6.1025397475125365: Sending message <Hello:> to Peer_1:basic
# Peer_2:basic INFO 6.1492366182920755: Received message <Hello:> from Peer_6:basic
# Peer_2:basic INFO 6.251658566746742: Received message <Hello:> from Peer_8:basic
# Peer_2:basic INFO 6.3721936905685155: Received message <Hello:> from Peer_19:basic
# Peer_2:basic INFO 6.404074010564553: Received message <Hello:> from Peer_11:basic
# Peer_2:basic INFO 6.61601276865076: Received message <Hello:> from Peer_16:basic
# Peer_2:basic INFO 6.903350597757948: Received message <Hello:> from Peer_18:basic
# Peer_2:basic INFO 6.944386781045156: Connecting to Peer_3:basic
# Peer_2:basic INFO 7.138069504567317: Received message <Hello:> from Peer_9:basic
# Peer_2:basic INFO 7.193973077257997: Received message <Hello:> from Peer_8:basic
# Peer_2:basic INFO 7.194477670992101: Received message <Hello:> from Peer_5:basic
# Peer_2:basic INFO 7.205284662390724: Received message <Hello:> from Peer_12:basic
# Peer_2:basic INFO 7.89465729241215: Received message <Hello:> from Peer_12:basic
# Peer_2:basic INFO 7.979997090409639: Received message <Hello:> from Peer_15:basic
# Peer_2:basic INFO 8.198766072631138: Received message <Hello:> from Peer_15:basic
# Peer_2:basic INFO 8.47155118497304: Received message <Hello:> from Peer_10:basic
# Peer_2:basic INFO 8.675127861278739: Received message <Hello:> from Peer_8:basic
# Peer_2:basic INFO 8.76806071634064: Received message <Hello:> from Peer_16:basic
# Peer_2:basic INFO 8.8383316616521: Received message <Hello:> from Peer_13:basic
# Peer_2:basic INFO 8.9084429193921: Received message <Hello:> from Peer_11:basic
# Peer_2:basic INFO 9.364365809676222: Received message <Hello:> from Peer_18:basic
# Peer_2:basic INFO 9.836576152388504: Received message <Hello:> from Peer_6:basic
Sending message <Pong:> to Peer_16:basic
# Peer_2:basic INFO 9005.360488519436: Received message <Ping:> from Peer_6:basic
# Peer_2:basic INFO 9005.360488519436: Sending message <Pong:> to Peer_6:basic
# Peer_2:basic INFO 9005.540464924941: Received message <Ping:> from Peer_11:basic
# Peer_2:basic INFO 9005.540464924941: Sending message <Pong:> to Peer_11:basic
# Peer_2:basic INFO 9005.606551901534: Received message <Ping:> from Peer_18:basic
# Peer_2:basic INFO 9005.606551901534: Sending message <Pong:> to Peer_18:basic
# Peer_2:basic INFO 9005.65394879487: Received message <Ping:> from Peer_17:basic
# Peer_2:basic INFO 9005.65394879487: Sending message <Pong:> to Peer_17:basic
# Peer_2:basic INFO 9005.78294309839: Received message <Ping:> from Peer_12:basic
# Peer_2:basic INFO 9005.78294309839: Sending message <Pong:> to Peer_12:basic
# Peer_2:basic INFO 9005.806243123898: Received message <Ping:> from Peer_13:basic
# Peer_2:basic INFO 9005.806243123898: Sending message <Pong:> to Peer_13:basic
# Peer_2:basic INFO 9005.992680329424: Received message <Ping:> from Peer_10:basic
# Peer_2:basic INFO 9005.992680329424: Sending message <Pong:> to Peer_10:basic
# Peer_2:basic INFO 9006.038508632184: Received message <Ping:> from Peer_3:basic
# Peer_2:basic INFO 9006.038508632184: Sending message <Pong:> to Peer_3:basic
# Peer_2:basic INFO 9006.072609334: Received message <Ping:> from Peer_8:basic
# Peer_2:basic INFO 9006.072609334: Sending message <Pong:> to Peer_8:basic
# Peer_2:basic INFO 9006.304483061222: Received message <Ping:> from Peer_15:basic
# Peer_2:basic INFO 9006.304483061222: Sending message <Pong:> to Peer_15:basic
# Peer_2:basic INFO 9006.361491678646: Received message <Ping:> from Peer_9:basic
# Peer_2:basic INFO 9006.361491678646: Sending message <Pong:> to Peer_9:basic
# Peer_2:basic INFO 9006.381563732206: Received message <Ping:> from Peer_5:basic
# Peer_2:basic INFO 9006.381563732206: Sending message <Pong:> to Peer_5:basic
# Peer_2:basic INFO 9006.742110612182: Received message <Ping:> from Peer_19:basic
# Peer_2:basic INFO 9006.742110612182: Sending message <Pong:> to Peer_19:basic
# Peer_2:basic INFO 9006.838052564437: Received message <Pong:> from Peer_4:basic
# Peer_2:basic INFO 9007.040633496707: Received message <Ping:> from Peer_16:basic
# Peer_2:basic INFO 9007.040633496707: Sending message <Pong:> to Peer_16:basic
# Peer_2:basic INFO 9007.334488605538: Received message <Pong:> from Peer_5:basic
# Peer_2:basic INFO 9007.903841477886: Received message <Ping:> from Peer_1:basic
# Peer_2:basic INFO 9007.903841477886: Sending message <Pong:> to Peer_1:basic
# Peer_2:basic INFO 9008.066941196443: Received message <Ping:> from Peer_3:basic
# Peer_2:basic INFO 9008.066941196443: Sending message <Pong:> to Peer_3:basic
# Peer_2:basic INFO 9008.105084693185: Received message <Ping:> from Peer_12:basic
# Peer_2:basic INFO 9008.105084693185: Sending message <Pong:> to Peer_12:basic
# Peer_2:basic INFO 9008.14227136631: Received message <Pong:> from Peer_15:basic
# Peer_2:basic INFO 9008.389211432062: Received message <Pong:> from Peer_12:basic
# Peer_2:basic INFO 9008.952725563851: Received message <Pong:> from Peer_18:basic
# Peer_2:basic INFO 9008.969986707902: Received message <Pong:> from Peer_8:basic
# Peer_2:basic INFO 9009.417932115653: Received message <Pong:> from Peer_6:basic
# Peer_2:basic INFO 9009.43188065513: Received message <Pong:> from Peer_7:basic
# Peer_2:basic INFO 9009.492520985894: Received message <Pong:> from Peer_16:basic
# Peer_2:basic INFO 9009.554247222079: Received message <Pong:> from Peer_10:basic
# Peer_2:basic INFO 9009.654140983585: Received message <Pong:> from Peer_7:basic
# Peer_2:basic INFO 9009.654876914718: Received message <Pong:> from Peer_3:basic
# Peer_2:basic INFO 9009.68310930963: Received message <Pong:> from Peer_13:basic
# Peer_2:basic INFO 9009.780981765034: Received message <Pong:> from Peer_12:basic
# Peer_2:basic INFO 9009.802693173177: Received message <Pong:> from Peer_16:basic
# Peer_2:basic INFO 9009.921302980907: Received message <Pong:> from Peer_5:basic
# Peer_2:basic INFO 9009.960293303282: Received message <Pong:> from Peer_19:basic
# Peer_2:basic INFO 9010.202909810703: Received message <Pong:> from Peer_18:basic
# Peer_2:basic INFO 9010.36464905784: Received message <Pong:> from Peer_11:basic
# Peer_2:basic INFO 9010.399111854966: Received message <Pong:> from Peer_3:basic
# Peer_2:basic INFO 9010.417552436227: Received message <Pong:> from Peer_9:basic
# Peer_2:basic INFO 9010.49552326925: Received message <Pong:> from Peer_6:basic
# Peer_2:basic INFO 9010.635567955771: Received message <Pong:> from Peer_17:basic
# Peer_2:basic INFO 9012.109081851906: Received message <Pong:> from Peer_10:basic
# Peer_2:basic INFO 9012.326373547818: Received message <Pong:> from Peer_8:basic
# Peer_2:basic INFO 9012.56402004168: Received message <Pong:> from Peer_9:basic
# Peer_2:basic INFO 9012.83552717146: Received message <Pong:> from Peer_1:basic
# Peer_2:basic INFO 9013.08975794756: Received message <Pong:> from Peer_17:basic

# %%
from p2psimpy.services.connection_manager import P2PConnectionManager

num_peers = 20

topology_specs = {i:{'type': 'basic'} for i in range(1, num_peers+1)}

class ConnectionConfig(Config):
    min_peers = 8
    max_peers = 12

peer_types = {'basic': PeerType(PeerConfig, {P2PConnectionManager: ConnectionConfig})}
#nikos, changed it accordingly to accomodate 20 nodes

# %%
sim = BaseSimulation(Locations, topology_specs, peer_types, logger_dir='logs2')

# Let's run the simulation for 5 seconds
sim.run(10_000)
#nikos, changed it to 10 seconds to evaluate the phenomenon further

# %%
G1 = sim.get_graph()
nx.draw_networkx(G1)

# %%
with open('logs2/Peer_10:basic.log') as s:
    print(s.read())
# Out:
# Peer_10:basic WARNING 0: Not enough peers, fetching more (0, 8)
# Peer_10:basic INFO 4.6413365519343: Connecting to Peer_21:bootstrap
# Peer_10:basic INFO 9.643075399680868: Received message <RequestPeers:> from Peer_21:bootstrap
# Peer_10:basic INFO 9.643075399680868: Sending message <PeerList> to Peer_21:bootstrap
# Peer_10:basic INFO 9.75711993945116: Received message <Hello:> from Peer_21:bootstrap
# Peer_10:basic WARNING 500: Not enough peers, fetching more (1, 8)
# Peer_10:basic INFO 500: Sending message <RequestPeers:> to Peer_21:bootstrap
# Peer_10:basic INFO 510.0917609939272: Received message <PeerList> from Peer_21:bootstrap
# Peer_10:basic WARNING 1000: Not enough peers, fetching more (1, 8)
# Peer_10:basic INFO 1000: Sending message <RequestPeers:> to Peer_21:bootstrap
# Peer_10:basic INFO 1004.4287635350137: Received message <Hello:> from Peer_14:basic
# Peer_10:basic INFO 1004.4287635350137: Connecting to Peer_14:basic
# Peer_10:basic INFO 1004.4287635350137: Sending message <Hello:> to Peer_14:basic
# Peer_10:basic INFO 1004.4287635350137: Sending message <RequestPeers:> to Peer_14:basic
# Peer_10:basic INFO 1005.5583756877387: Connecting to Peer_20:basic
# Peer_10:basic INFO 1005.5743229256282: Received message <Hello:> from Peer_15:basic
# Peer_10:basic INFO 1005.5743229256282: Connecting to Peer_15:basic
# Peer_10:basic INFO 1005.5743229256282: Sending message <Hello:> to Peer_15:basic
# Peer_10:basic INFO 1005.5743229256282: Sending message <RequestPeers:> to Peer_15:basic
# Peer_10:basic INFO 1008.5372041185828: Received message <RequestPeers:> from Peer_20:basic
# Peer_10:basic INFO 1008.5372041185828: Sending message <PeerList> to Peer_20:basic
# Peer_10:basic INFO 1009.942615976426: Received message <Hello:> from Peer_20:basic
# Peer_10:basic INFO 1010.0456113572535: Received message <PeerList> from Peer_21:bootstrap
# Peer_10:basic INFO 1013.9513609153751: Received message <PeerList> from Peer_15:basic
# Peer_10:basic INFO 1014.4930492287755: Received message <PeerList> from Peer_14:basic
# Peer_10:basic WARNING 1500: Not enough peers, fetching more (4, 8)
# Peer_10:basic INFO 1500: Sending message <RequestPeers:> to Peer_20:basic
# Peer_10:basic INFO 1500: Sending message <RequestPeers:> to Peer_15:basic
# Peer_10:basic INFO 1500: Sending message <RequestPeers:> to Peer_14:basic
# Peer_10:basic INFO 1500: Sending message <RequestPeers:> to Peer_21:bootstrap
# Peer_10:basic INFO 1503.2390973448548: Received message <RequestPeers:> from Peer_20:basic
# Peer_10:basic INFO 1503.2390973448548: Sending message <PeerList> to Peer_20:basic
# Peer_10:basic INFO 1503.777169484524: Received message <RequestPeers:> from Peer_15:basic
# Peer_10:basic INFO 1503.777169484524: Sending message <PeerList> to Peer_15:basic
# Peer_10:basic INFO 1504.0256591266027: Connecting to Peer_18:basic
# Peer_10:basic INFO 1504.635497007082: Received message <RequestPeers:> from Peer_14:basic
# Peer_10:basic INFO 1504.635497007082: Sending message <PeerList> to Peer_14:basic
# Peer_10:basic INFO 1508.9937795654098: Received message <Hello:> from Peer_18:basic
# Peer_10:basic INFO 1509.4785005911035: Received message <PeerList> from Peer_14:basic
# Peer_10:basic INFO 1509.9272215463268: Received message <PeerList> from Peer_21:bootstrap
# Peer_10:basic INFO 1510.13683013192: Received message <RequestPeers:> from Peer_18:basic
# Peer_10:basic INFO 1510.13683013192: Sending message <PeerList> to Peer_18:basic
# Peer_10:basic INFO 1510.870410632296: Received message <PeerList> from Peer_15:basic
# Peer_10:basic INFO 1512.960825287881: Received message <PeerList> from Peer_20:basic
# Peer_10:basic WARNING 2000: Not enough peers, fetching more (5, 8)
# Peer_10:basic INFO 2000: Sending message <RequestPeers:> to Peer_18:basic
# Peer_10:basic INFO 2000: Sending message <RequestPeers:> to Peer_15:basic
# Peer_10:basic INFO 2000: Sending message <RequestPeers:> to Peer_21:bootstrap
# Peer_10:basic INFO 2000: Sending message <RequestPeers:> to Peer_20:basic
# Peer_10:basic INFO 2000: Sending message <RequestPeers:> to Peer_14:basic
# Peer_10:basic INFO 2004.1100197228857: Received message <RequestPeers:> from Peer_15:basic
# Peer_10:basic INFO 2004.1100197228857: Sending message <PeerList> to Peer_15:basic
# Peer_10:basic INFO 2004.447189568522: Connecting to Peer_9:basic
# Peer_10:basic INFO 2004.5301825428057: Received message <RequestPeers:> from Peer_20:basic
# Peer_10:basic INFO 2004.5301825428057: Sending message <PeerList> to Peer_20:basic
# Peer_10:basic INFO 2004.5644007166138: Received message <RequestPeers:> from Peer_18:basic
# Peer_10:basic INFO 2004.5644007166138: Sending message <PeerList> to Peer_18:basic
# Peer_10:basic INFO 2004.9213491919295: Received message <Hello:> from Peer_8:basic
# Peer_10:basic INFO 2004.9213491919295: Connecting to Peer_8:basic
# Peer_10:basic INFO 2004.9213491919295: Sending message <Hello:> to Peer_8:basic
# Peer_10:basic INFO 2004.9213491919295: Sending message <RequestPeers:> to Peer_8:basic
# Peer_10:basic INFO 2004.9900189424272: Received message <Hello:> from Peer_2:basic
# Peer_10:basic INFO 2004.9900189424272: Connecting to Peer_2:basic
# Peer_10:basic INFO 2004.9900189424272: Sending message <Hello:> to Peer_2:basic
# Peer_10:basic INFO 2004.9900189424272: Sending message <RequestPeers:> to Peer_2:basic
# Peer_10:basic INFO 2005.1035522254758: Received message <Hello:> from Peer_19:basic
# Peer_10:basic INFO 2005.1035522254758: Connecting to Peer_19:basic
# Peer_10:basic INFO 2005.1035522254758: Sending message <Hello:> to Peer_19:basic
# Peer_10:basic INFO 2005.1035522254758: Sending message <RequestPeers:> to Peer_19:basic
# Peer_10:basic INFO 2005.1508602634997: Received message <Hello:> from Peer_13:basic
# Peer_10:basic INFO 2005.1508602634997: Connecting to Peer_13:basic
# Peer_10:basic INFO 2005.1508602634997: Sending message <Hello:> to Peer_13:basic
# Peer_10:basic INFO 2005.1508602634997: Sending message <RequestPeers:> to Peer_13:basic
# Peer_10:basic INFO 2005.1546306216333: Received message <RequestPeers:> from Peer_14:basic
# Peer_10:basic INFO 2005.1546306216333: Sending message <PeerList> to Peer_14:basic
# Peer_10:basic INFO 2007.559123630817: Received message <PeerList> from Peer_15:basic
# Peer_10:basic INFO 2008.160981017952: Received message <PeerList> from Peer_20:basic
# Peer_10:basic INFO 2008.9110269054497: Received message <Hello:> from Peer_9:basic
# Peer_10:basic INFO 2009.476297386965: Received message <PeerList> from Peer_14:basic
# Peer_10:basic INFO 2009.6817584678877: Received message <RequestPeers:> from Peer_9:basic
# Peer_10:basic INFO 2009.6817584678877: Sending message <PeerList> to Peer_9:basic
# Peer_10:basic INFO 2009.8578454017745: Received message <PeerList> from Peer_21:bootstrap
# Peer_10:basic INFO 2011.5135395232699: Received message <PeerList> from Peer_18:basic
# Peer_10:basic INFO 2014.8978633086485: Received message <PeerList> from Peer_13:basic
# Peer_10:basic INFO 2015.0580986336875: Received message <PeerList> from Peer_19:basic
# Peer_10:basic INFO 2015.3823527573243: Received message <PeerList> from Peer_8:basic
# Peer_10:basic INFO 2017.444711506906: Received message <PeerList> from Peer_2:basic
# Peer_10:basic INFO 2504.193198196844: Received message <RequestPeers:> from Peer_20:basic
# Peer_10:basic INFO 2504.193198196844: Sending message <PeerList> to Peer_20:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_21:bootstrap
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_14:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_15:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_18:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_9:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_8:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_2:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_19:basic
# Peer_10:basic INFO 3000: Sending message <Ping:> to Peer_13:basic
# Peer_10:basic INFO 3004.53716918149: Received message <Ping:> from Peer_2:basic
# Peer_10:basic INFO 3004.53716918149: Sending message <Pong:> to Peer_2:basic
# Peer_10:basic INFO 3004.8044091449215: Received message <Ping:> from Peer_9:basic
# Peer_10:basic INFO 3004.8044091449215: Sending message <Pong:> to Peer_9:basic
# Peer_10:basic INFO 3004.8749396895423: Received message <Ping:> from Peer_15:basic
# Peer_10:basic INFO 3004.8749396895423: Sending message <Pong:> to Peer_15:basic
# Peer_10:basic INFO 3005.0948751283227: Received message <Ping:> from Peer_8:basic
# Peer_10:basic INFO 3005.0948751283227: Sending message <Pong:> to Peer_8:basic
# Peer_10:basic INFO 3005.104629367183: Received message <Ping:> from Peer_19:basic
# Peer_10:basic INFO 3005.104629367183: Sending message <Pong:> to Peer_19:basic
# Peer_10:basic INFO 3005.186377090076: Received message <Ping:> from Peer_21:bootstrap
# Peer_10:basic INFO 3005.186377090076: Sending message <Pong:> to Peer_21:bootstrap
# Peer_10:basic INFO 3005.3147303168234: Received message <Ping:> from Peer_14:basic
# Peer_10:basic INFO 3005.3147303168234: Sending message <Pong:> to Peer_14:basic
# Peer_10:basic INFO 3005.3156846040315: Received message <Ping:> from Peer_13:basic
# Peer_10:basic INFO 3005.3156846040315: Sending message <Pong:> to Peer_13:basic
# Peer_10:basic INFO 3006.093666833995: Received message <Ping:> from Peer_18:basic
# Peer_10:basic INFO 3006.093666833995: Sending message <Pong:> to Peer_18:basic
# Peer_10:basic INFO 3009.4484351527963: Received message <Pong:> from Peer_8:basic
# Peer_10:basic INFO
Sending message <Pong:> to Peer_14:basic
# Peer_10:basic INFO 8005.401654061401: Received message <Ping:> from Peer_8:basic
# Peer_10:basic INFO 8005.401654061401: Sending message <Pong:> to Peer_8:basic
# Peer_10:basic INFO 8006.117183378184: Received message <Ping:> from Peer_15:basic
# Peer_10:basic INFO 8006.117183378184: Sending message <Pong:> to Peer_15:basic
# Peer_10:basic INFO 8008.797927300715: Received message <Pong:> from Peer_2:basic
# Peer_10:basic INFO 8009.568935749042: Received message <Pong:> from Peer_18:basic
# Peer_10:basic INFO 8009.870033444249: Received message <Pong:> from Peer_15:basic
# Peer_10:basic INFO 8010.081002154394: Received message <Pong:> from Peer_13:basic
# Peer_10:basic INFO 8010.244803393956: Received message <Pong:> from Peer_8:basic
# Peer_10:basic INFO 8010.290686985789: Received message <Pong:> from Peer_9:basic
# Peer_10:basic INFO 8010.297340960117: Received message <Pong:> from Peer_21:bootstrap
# Peer_10:basic INFO 8010.799549363711: Received message <Pong:> from Peer_14:basic
# Peer_10:basic INFO 8010.890138303479: Received message <Pong:> from Peer_19:basic
# Peer_10:basic INFO 8500: Sending message <Ping:> to Peer_20:basic
# Peer_10:basic INFO 8504.73877359528: Received message <Ping:> from Peer_20:basic
# Peer_10:basic INFO 8504.73877359528: Sending message <Pong:> to Peer_20:basic
# Peer_10:basic INFO 8510.91989463351: Received message <Pong:> from Peer_20:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_21:bootstrap
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_14:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_15:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_18:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_9:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_8:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_2:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_19:basic
# Peer_10:basic INFO 9000: Sending message <Ping:> to Peer_13:basic
# Peer_10:basic INFO 9004.763869137478: Received message <Ping:> from Peer_8:basic
# Peer_10:basic INFO 9004.763869137478: Sending message <Pong:> to Peer_8:basic
# Peer_10:basic INFO 9004.805210125041: Received message <Ping:> from Peer_21:bootstrap
# Peer_10:basic INFO 9004.805210125041: Sending message <Pong:> to Peer_21:bootstrap
# Peer_10:basic INFO 9004.817941116773: Received message <Ping:> from Peer_15:basic
# Peer_10:basic INFO 9004.817941116773: Sending message <Pong:> to Peer_15:basic
# Peer_10:basic INFO 9004.85969030935: Received message <Ping:> from Peer_19:basic
# Peer_10:basic INFO 9004.85969030935: Sending message <Pong:> to Peer_19:basic
# Peer_10:basic INFO 9005.020837049504: Received message <Ping:> from Peer_9:basic
# Peer_10:basic INFO 9005.020837049504: Sending message <Pong:> to Peer_9:basic
# Peer_10:basic INFO 9005.035551231415: Received message <Ping:> from Peer_14:basic
# Peer_10:basic INFO 9005.035551231415: Sending message <Pong:> to Peer_14:basic
# Peer_10:basic INFO 9005.348171143129: Received message <Ping:> from Peer_18:basic
# Peer_10:basic INFO 9005.348171143129: Sending message <Pong:> to Peer_18:basic
# Peer_10:basic INFO 9005.349658596264: Received message <Ping:> from Peer_13:basic
# Peer_10:basic INFO 9005.349658596264: Sending message <Pong:> to Peer_13:basic
# Peer_10:basic INFO 9005.541429603787: Received message <Ping:> from Peer_2:basic
# Peer_10:basic INFO 9005.541429603787: Sending message <Pong:> to Peer_2:basic
# Peer_10:basic INFO 9008.662523725543: Received message <Pong:> from Peer_15:basic
# Peer_10:basic INFO 9008.998994980053: Received message <Pong:> from Peer_2:basic
# Peer_10:basic INFO 9009.417064451372: Received message <Pong:> from Peer_13:basic
# Peer_10:basic INFO 9009.516289796276: Received message <Pong:> from Peer_21:bootstrap
# Peer_10:basic INFO 9009.667304208715: Received message <Pong:> from Peer_18:basic
# Peer_10:basic INFO 9009.869891696: Received message <Pong:> from Peer_14:basic
# Peer_10:basic INFO 9010.006373588196: Received message <Pong:> from Peer_9:basic
# Peer_10:basic INFO 9010.150498569059: Received message <Pong:> from Peer_19:basic
# Peer_10:basic INFO 9010.317967132745: Received message <Pong:> from Peer_8:basic
# Peer_10:basic INFO 9500: Sending message <Ping:> to Peer_20:basic
# Peer_10:basic INFO 9506.79339374238: Received message <Ping:> from Peer_20:basic
# Peer_10:basic INFO 9506.79339374238: Sending message <Pong:> to Peer_20:basic
# Peer_10:basic INFO 9509.832786554645: Received message <Pong:> from Peer_20:basic
